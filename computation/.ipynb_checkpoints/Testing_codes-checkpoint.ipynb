# %%
"""
Generates a csv file for a solar cell composed of 3 layers of  P3HT, 1 layer of 2:1 P3HT:PCBM, 4 layers of 1:1
P3HT:PCBM (2 with import and 2 with import2), 1 layer of 1:2 P3HT:PCBM,
and 3 layers of PCBM, for a coarsely graded "sandwich" structure
"""
import os
import pandas as pd
from multiprocessing import Pool
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.colors as mcolors


"""
import2_mctotal.csv = 100% acceptor (represented by all red)
import2_mc15.csv = 3:1 (acceptor : donor)
import2_mc7.csv = 2:1
import2_mc3.csv = 1:1
import_mc3.csv = 1:1
import_mc7.csv = 1:2
import_mc15.csv = 1:3
import_mctotal.csv = 100% donor (represented by all blue)

c stands for the charge and z stands for the z axis in the following code
"""


class GradedStructureGenerator:
    # paths for donor/acceptor ratio
    DATA_DIRECTOR = os.path.dirname('__file__')+'/../src/data'
    path0 = DATA_DIRECTOR+"/import_mc3.csv"
    path1 = DATA_DIRECTOR+"/import_mc7.csv"
    path2 = DATA_DIRECTOR+"/import_mctotal.csv"
    path3 = DATA_DIRECTOR+"/import2_mc3.csv"
    path4 = DATA_DIRECTOR+"/import2_mc7.csv"
    path5 = DATA_DIRECTOR+"/import2_mctotal.csv"
    path6 = DATA_DIRECTOR+"/import_mc15.csv"
    path7 = DATA_DIRECTOR+"/import2_mc15.csv"
    # file need by the program
    code_file_path = DATA_DIRECTOR+"/import.csv"

    def __init__(self, process_id, ratio_and_layer, working_directory):
        print(print(os.path.dirname('__file__')))
        self.working_directory=working_directory
        self.process_id = process_id
        self.list_csv = self.read_csv_in_parallel()
        # lf stands for file used for the corresponding layer
        # the numbers indicate the layer number while the corresponding file indicates the file used to encpsulate the layer
        # it will come from the gui later
        self.lf0 = self.list_csv[2]
        self.lf1 = self.list_csv[2]
        self.lf2 = self.list_csv[2]

        self.lf3 = self.list_csv[1]

        self.lf4 = self.list_csv[0]
        self.lf5 = self.list_csv[0]

        self.lf6 = self.list_csv[3]
        self.lf7 = self.list_csv[3]

        self.lf8 = self.list_csv[4]

        self.lf9 = self.list_csv[5]
        self.lf10 = self.list_csv[5]
        self.lf11 = self.list_csv[5]
        # file used by the code
        self.code_file = self.list_csv[8]

        # third column, # fourth column
        self.z0, self.c0 = self.lf0[2], self.lf0[3]
        self.z1, self.c1 = self.lf1[2], self.lf1[3]
        self.z2, self.c2 = self.lf2[2], self.lf2[3]
        self.z3, self.c3 = self.lf3[2], self.lf3[3]
        self.z4, self.c4 = self.lf4[2], self.lf4[3]
        self.z5, self.c5 = self.lf5[2], self.lf5[3]
        self.z6, self.c6 = self.lf6[2], self.lf6[3]
        self.z7, self.c7 = self.lf7[2], self.lf7[3]
        self.z8, self.c8 = self.lf8[2], self.lf8[3]
        self.z9, self.c9 = self.lf9[2], self.lf9[3]
        self.z10, self.c10 = self.lf10[2], self.lf10[3]
        self.z11, self.c11 = self.lf11[2], self.lf11[3]
        self.z = self.code_file[2]
        self.c = self.code_file[3]

    def read_csv(self, filename):
        return pd.read_csv(filename, header=None)

    def read_csv_in_parallel(self):
        list_csv = [0]*9
        with Pool(processes=4) as pool:
            list_csv = pool.map(self.read_csv, [GradedStructureGenerator.path0, GradedStructureGenerator.path1, GradedStructureGenerator.path2, GradedStructureGenerator.path3,
                                                GradedStructureGenerator.path4, GradedStructureGenerator.path5, GradedStructureGenerator.path6, GradedStructureGenerator.path7, GradedStructureGenerator.code_file_path])
        return list_csv

    def add_c_to_structure(self, row_start, row_end):
        # 600000
        for m in range(row_start, row_end):
            if(self.z[m] >= 0 and self.z[m] < 5):
                self.c[m] = self.c11[m]
            elif (self.z[m] >= 5 and self.z[m] < 10):
                self.c[m] = self.c10[m]
            elif (self.z[m] >= 10 and self.z[m] < 15):
                self.c[m] = self.c9[m]
            elif (self.z[m] >= 15 and self.z[m] < 20):
                self.c[m] = self.c8[m]
            elif (self.z[m] >= 20 and self.z[m] < 25):
                self.c[m] = self.c7[m]
            elif (self.z[m] >= 25 and self.z[m] < 30):
                self.c[m] = self.c6[m]
            elif (self.z[m] >= 30 and self.z[m] < 35):
                self.c[m] = self.c5[m]
            elif (self.z[m] >= 35 and self.z[m] < 40):
                self.c[m] = self.c4[m]
            elif (self.z[m] >= 40 and self.z[m] < 45):
                self.c[m] = self.c3[m]
            elif (self.z[m] >= 45 and self.z[m] < 50):
                self.c[m] = self.c2[m]
            elif (self.z[m] >= 50 and self.z[m] < 55):
                self.c[m] = self.c1[m]
            elif (self.z[m] >= 55 and self.z[m] <= 60):
                self.c[m] = self.c0[m]

    def generate_structure(self):
        # ranges = self.generate_ranges()
        # with Pool(processes=4) as pool:
        #     pool.map(self.add_c_to_structure, [(0,150000),(150000,300000),(300000,450000),(450000,600000)])
        self.add_c_to_structure(0, 600000)
        self.code_file[3] = self.c
        # directory_of_python_script = os.path.dirname(os.path.abspath(__file__))

        file_name = "structure"+str(self.process_id)+".csv"
        self.code_file.to_csv(os.path.join(
            self.working_directory, file_name), header=False, index=False)

        fig = plt.figure(figsize=(5,4))
        ax = fig.add_subplot(111, projection='3d')
        ax.scatter(self.code_file[0], self.code_file[1], self.code_file[2],s=10,c=self.code_file[3],
                   cmap=mcolors.ListedColormap(["blue","red"]))
        plt.title("Red represents acceptor and Blue represents donor")
        plt.show()


# if __name__ == '__main__':
#     path="/Users/abebeamare/Desktop/Desktop/spring2021/ECE493/FinalProject/src/data"
#     process1 = GradedStructureGenerator(25, {}, path)
#     process1.generate_structure()

# %%
path="/Users/abebeamare/Desktop/Desktop/spring2021/ECE493/FinalProject/src/data"
process1 = GradedStructureGenerator(25, {}, path)
process1.generate_structure()
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Applications/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-feeec06f7714>", line 88, in read_csv
#     return pd.read_csv(filename, header=None)
#   File "/Applications/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 676, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/Applications/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 448, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/Applications/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 880, in __init__
#     self._make_engine(self.engine)
#   File "/Applications/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 1114, in _make_engine
#     self._engine = CParserWrapper(self.f, **self.options)
#   File "/Applications/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 1891, in __init__
#     self._reader = parsers.TextReader(src, **kwds)
#   File "pandas/_libs/parsers.pyx", line 374, in pandas._libs.parsers.TextReader.__cinit__
#   File "pandas/_libs/parsers.pyx", line 673, in pandas._libs.parsers.TextReader._setup_parser_source
# FileNotFoundError: [Errno 2] File /../src/data/import_mctotal.csv does not exist: '/../src/data/import_mctotal.csv'
# """
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-83fdc87cd66e> in <module>
#       1 path="/Users/abebeamare/Desktop/Desktop/spring2021/ECE493/FinalProject/src/data"
# ----> 2 process1 = GradedStructureGenerator(25, {}, path)
#       3 process1.generate_structure()
#
# <ipython-input-5-feeec06f7714> in __init__(self, process_id, ratio_and_layer, working_directory)
#      45         self.working_directory=working_directory
#      46         self.process_id = process_id
# ---> 47         self.list_csv = self.read_csv_in_parallel()
#      48         # lf stands for file used for the corresponding layer
#      49         # the numbers indicate the layer number while the corresponding file indicates the file used to encpsulate the layer
#
# <ipython-input-5-feeec06f7714> in read_csv_in_parallel(self)
#      92         with Pool(processes=4) as pool:
#      93             list_csv = pool.map(self.read_csv, [GradedStructureGenerator.path0, GradedStructureGenerator.path1, GradedStructureGenerator.path2, GradedStructureGenerator.path3,
# ---> 94                                                 GradedStructureGenerator.path4, GradedStructureGenerator.path5, GradedStructureGenerator.path6, GradedStructureGenerator.path7, GradedStructureGenerator.code_file_path])
#      95         return list_csv
#      96
#
# /Applications/anaconda3/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# /Applications/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# FileNotFoundError: [Errno 2] File /../src/data/import_mctotal.csv does not exist: '/../src/data/import_mctotal.csv'

# %%
ls
# Out:
# Main.java   data/       frontend/   model/      pythonPart/ style.css
